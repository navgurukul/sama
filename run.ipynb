# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
cd Users/lenovo/Desktop/Sama_Internship/sama
# Out:
# [Errno 2] No such file or directory: 'Users/lenovo/Desktop/Sama_Internship/sama'
# /content

# %%
# !!python test.py
# Out:
# ["python3: can't open file '/content/test.py': [Errno 2] No such file or directory"]
